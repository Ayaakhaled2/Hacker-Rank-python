# %%
# Q1) Python If-Else

# %%
#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
if n % 2 != 0:
    print('Weird')
elif n % 2 == 0:
    if n >= 2 and n <= 5 : 
        print('Not Weird')
    elif n >= 6 and n <= 20:
        print('Weird')
    else:
        print('Not Weird')

# %%
# Q2) Arithmetic Operators

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
print( a + b )
print( a - b )
print( b * a )

# %%
# Q3) Python: Division

# %%
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    
print( a // b)
print( a / b )

# %%
# Q4) Loops

# %%
if __name__ == '__main__':
    n = int(input())
for i in range(0 , n):
    print(i ** 2)

# %%
# Q5) Print Function

# %%
if __name__ == '__main__':
    n = int(input())
num = ''    
for i in range(1 , n+1 ):
    num = num + str(i)
    
print(num)
